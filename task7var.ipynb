# %% [markdown]
# <a href="https://colab.research.google.com/github/varnikabaskar/data-science/blob/main/task7var.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Apply and explore various plotting functions on UCI data set for performingthefollowing:a) Correlation and scatter plots
# b) Histograms
# c) Three-dimensional plotting

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Load the Iris dataset (replace this with your dataset)
iris = sns.load_dataset('iris')

# a) Correlation and scatter plots
correlation_matrix = iris.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# Scatter plot between two variables
sns.scatterplot(x='sepal_length', y='sepal_width', data=iris)
plt.title('Scatter Plot between Sepal Length and Sepal Width')
plt.show()

# b) Histograms
iris['sepal_length'].plot.hist(bins=20, edgecolor='black')
plt.title('Histogram of Sepal Length')
plt.xlabel('Sepal Length')
plt.ylabel('Frequency')
plt.show()

# c) Three-dimensional plotting
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(iris['sepal_length'], iris['sepal_width'], iris['petal_length'], c='blue', marker='o')

ax.set_xlabel('Sepal Length')
ax.set_ylabel('Sepal Width')
ax.set_zlabel('Petal Length')

plt.title('3D Scatter Plot')
plt.show()
# Out:
# <ipython-input-1-443e9e2dda1e>:10: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = iris.corr()

# %% [markdown]
# `
#
# Apply and explore various plotting functions on Pima Indians Diabetes data set for performingthefollowing:
# g) Normal values
# h) Density and contour plots
# i) Three-dimensional plotting

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from google.colab import drive
drive.mount('/content/drive')


diabetes_df = pd.read_csv('/content/drive/MyDrive/diabetes.csv')

print(diabetes_df.head())

# g) Normal values (boxplot)
sns.boxplot(data=diabetes_df)
plt.title('Boxplot of Pima Indians Diabetes Dataset')
plt.show()

# h) Density and contour plots
sns.kdeplot(data=diabetes_df, x='Age', y='BMI', fill=True, cmap='viridis', levels=20)
plt.title('Density and Contour Plot of Age vs. BMI')
plt.show()

# i) Three-dimensional plotting
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(diabetes_df['Age'], diabetes_df['BMI'], diabetes_df['Glucose'], c='blue', marker='o')

ax.set_xlabel('Age')
ax.set_ylabel('BMI')
ax.set_zlabel('Glucose')

plt.title('3D Scatter Plot of Age, BMI, and Glucose')
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# Apply and explore various plotting functions on UCI data set for performing the following:
# d) Normal values
# e) Density and contour plots
# f) Three-dimensional plotting

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# Generating a synthetic dataset for demonstration purposes
np.random.seed(42)
data = {
    'Feature1': np.random.normal(0, 1, 1000),
    'Feature2': np.random.normal(2, 1, 1000),
    'Feature3': np.random.normal(-2, 1, 1000),
}
df = pd.DataFrame(data)

# Display the first few rows of the dataset
print(df.head())

# d) Normal values (boxplot)
sns.boxplot(data=df)
plt.title('Boxplot of Synthetic Dataset')
plt.show()

# e) Density and contour plots
sns.kdeplot(data=df, x='Feature1', y='Feature2', fill=True, cmap='viridis', levels=20)
plt.title('Density and Contour Plot of Feature1 vs. Feature2')
plt.show()

# f) Three-dimensional plotting
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(df['Feature1'], df['Feature2'], df['Feature3'], c='blue', marker='o')

ax.set_xlabel('Feature1')
ax.set_ylabel('Feature2')
ax.set_zlabel('Feature3')

plt.title('3D Scatter Plot of Feature1, Feature2, and Feature3')
plt.show()
# Out:
#    Feature1  Feature2  Feature3
# 0  0.496714  3.399355 -2.675178
# 1 -0.138264  2.924634 -2.144519
# 2  0.647689  2.059630 -2.792420
# 3  1.523030  1.353063 -2.307962
# 4 -0.234153  2.698223 -3.893615

# %% [markdown]
# Write a Pandas program to select all columns, except one given column in a DataFrame. Sample Output:
# Original DataFrame
# col1 col2 col3
# 0 1 4 7
# 1 2 5 8
# 2 3 6 12
# 3 4 9 1
# 4 7 5 11
# All columns except 'col3':
# col1 col2
# 0 1 4
# 1 2 5
# 2 3 6
# 3 4 9
# 4 7 5

# %%
import pandas as pd

# Create a sample DataFrame
data = {
    'col1': [1, 2, 3, 4, 7],
    'col2': [4, 5, 6, 9, 5],
    'col3': [7, 8, 12, 1, 11]
}

df = pd.DataFrame(data)

# Display the original DataFrame
print("Original DataFrame:")
print(df)

# Select all columns except 'col3'
columns_except_col3 = df.drop('col3', axis=1)

# Display the result
print("\nAll columns except 'col3':")
print(columns_except_col3)
# Out:
# Original DataFrame:
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     8
# 2     3     6    12
# 3     4     9     1
# 4     7     5    11
#
# All columns except 'col3':
#    col1  col2
# 0     1     4
# 1     2     5
# 2     3     6
# 3     4     9
# 4     7     5

# %% [markdown]
# Write a Pandas program to check for inequality of two given DataFrames. Sample Output:
# Original DataFrames:
# W X Y Z
# 0 68.0 78.0 84 86
# 1 75.0 85.0 94 97
# 2 86.0 NaN 89 96
# 3 80.0 80.0 83 72
# 4 NaN 86.0 86 83
# W X Y Z
# 0 78.0 78 84 86
# 1 75.0 85 84 97
# 2 86.0 96 89 96
# 3 80.0 80 83 72
# 4 NaN 76 86 83
# Check for inequality of the said dataframes:
# W X Y Z
# 0 True False False False
# 1 False False True False
# Page 11 of 17
# 2 False True False False
# 3 False False False False
# 4 True True False False

# %%
import pandas as pd
import numpy as np

# Create two sample DataFrames
data1 = {
    'W': [68.0, 75.0, 86.0, 80.0, np.nan],
    'X': [78.0, 85.0, np.nan, 80.0, 86.0],
    'Y': [84, 94, 89, 83, 86],
    'Z': [86, 97, 96, 72, 83]
}

data2 = {
    'W': [78.0, 75.0, 86.0, 80.0, np.nan],
    'X': [78, 85, 96, 80, 76],
    'Y': [84, 84, 89, 83, 86],
    'Z': [86, 97, 96, 72, 83]
}

df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)

# Display the original DataFrames
print("Original DataFrames:")
print(df1)
print(df2)

# Check for inequality between the two DataFrames
inequality_result = df1 != df2

# Display the result
print("\nCheck for inequality of the said dataframes:")
print(inequality_result)
# Out:
# Original DataFrames:
#       W     X   Y   Z
# 0  68.0  78.0  84  86
# 1  75.0  85.0  94  97
# 2  86.0   NaN  89  96
# 3  80.0  80.0  83  72
# 4   NaN  86.0  86  83
#       W   X   Y   Z
# 0  78.0  78  84  86
# 1  75.0  85  84  97
# 2  86.0  96  89  96
# 3  80.0  80  83  72
# 4   NaN  76  86  83
#
# Check for inequality of the said dataframes:
#        W      X      Y      Z
# 0   True  False  False  False
# 1  False  False   True  False
# 2  False   True  False  False
# 3  False  False  False  False
# 4   True   True  False  False

# %% [markdown]
# i. Write a NumPy program to convert a list and tuple into arrays
# ii.Write a NumPy program to convert the values of Centigrade degrees intoFahrenheitdegrees and vice versa. Values have to be stored into a NumPy array

# %%
import numpy as np

# i. Convert a List into an Array
list_data = [1, 2, 3, 4, 5]
array_from_list = np.array(list_data)

# i. Convert a Tuple into an Array
tuple_data = (1, 2, 3, 4, 5)
array_from_tuple = np.array(tuple_data)

# Display the results
print("Array from List:")
print(array_from_list)

print("\nArray from Tuple:")
print(array_from_tuple)
# Out:
# Array from List:
# [1 2 3 4 5]
#
# Array from Tuple:
# [1 2 3 4 5]

# %%
import numpy as np

# ii. Convert Centigrade to Fahrenheit and Vice Versa
def celsius_to_fahrenheit(celsius):
    return (celsius * 9/5) + 32

def fahrenheit_to_celsius(fahrenheit):
    return (fahrenheit - 32) * 5/9

# Create a NumPy array of Centigrade temperatures
celsius_temperatures = np.array([0, 10, 20, 30, 40])

# Convert Centigrade to Fahrenheit
fahrenheit_temperatures = celsius_to_fahrenheit(celsius_temperatures)

# Convert Fahrenheit to Centigrade
converted_celsius_temperatures = fahrenheit_to_celsius(fahrenheit_temperatures)

# Display the results
print("Centigrade Temperatures:")
print(celsius_temperatures)

print("\nConverted Fahrenheit Temperatures:")
print(fahrenheit_temperatures)

print("\nConverted Centigrade Temperatures:")
print(converted_celsius_temperatures)
# Out:
# Centigrade Temperatures:
# [ 0 10 20 30 40]
#
# Converted Fahrenheit Temperatures:
# [ 32.  50.  68.  86. 104.]
#
# Converted Centigrade Temperatures:
# [ 0. 10. 20. 30. 40.]
